# %% [markdown]
# # I. Phân tích uy tín và niềm tin khách hàng

# %% [markdown]
# **[Q4]**: Hai mục tiêu chính cần xác định:
# - Điểm hài lòng, số đánh giá và số lượt thích của khách hàng ảnh hưởng như thế nào đến doanh số bán hàng?
# - So sánh hiệu quả bán hàng giữa các loại shop (Mall, Verified và shop thường) nhằm đánh giá mức độ ảnh hưởng của uy tín thương hiệu đến hành vi mua hàng
