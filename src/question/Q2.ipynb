# %% [markdown]
# # I. Phân tích chiến lược giá và khuyến mãi

# %% [markdown]
# **[Q2] Câu hỏi:** Hai mục tiêu chính cần xác định:
# - Mối quan hệ giữa phần trăm giảm giá và doanh số (trong tháng 3/2026 và tổng thể) là gì?, đồng thời so sánh giữa các nhóm sản phẩm mới, trung bình và lâu năm để đề xuất mức giảm giá phù hợp?
# - Xác định mối quan hệ giữa giảm giá và chính sách miễn phí vận chuyển, từ đó đánh giá liệu việc kết hợp cả hai hình thức khuyến mãi có giúp tăng doanh số hiệu quả hơn so với chỉ áp dụng một hình thức
