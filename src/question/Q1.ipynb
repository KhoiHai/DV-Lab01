# %% [markdown]
# # I. Phân tích hiệu suất bán hàng theo danh mục sản phẩm

# %% [markdown]
# **[Q1]**: Trong phạm vi dữ liệu thu thập được, hiệu suất bán hàng có sự khác biệt như thế nào giữa các danh mục mỹ phẩm trong:
# - Tháng 3/2026 nói riêng
# - Tổng thể nói chung
#
# Từ đó, đưa ra chiến lược lựa chọn danh mục cho shop
